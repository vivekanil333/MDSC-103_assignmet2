# %%
import numpy as np
import matplotlib.pyplot as plt
f = lambda x: x**2
x = np.linspace(-5,5,100)
delta=(1*10**(-5))
x1=4
x2=0
list=[x1]

for i in range(0,100):
    x2=x1-0.1*(2*x1)
    list.append(x2)
    if(not((x2-x2)<delta or(x2-x1)>-delta)):
        break
    x1=x2

    #print(x2)
    grad=[f(x) for x in  list]

plt.plot(x,f(x),color='r')
plt.plot(list,grad,color='g',marker='o')
plt.show()

# %%
def gradient_function(fun,grad_function,x0,learning_rate,delta,lower_range_limit,upper_range_limit):
    f=func
    g=grad_func
    x=np.linspace(lower_range_limit,upper_range_limit,200)
    xn=0
    list[x0]
    for i in range(0,100):
        xn=x0-(learning_rate*g(x0))
        list.append(xn)
        if(not((xn-x0)<delta or (xn-x0)>-delta)):
            break
        x0=xn
    print(xn)

    grad_descent_y=[f(i) for i in list]
    plt.plot(x,f(x))
    plt.xlabel("x-values")
    plt.ylabel("y-values")
    plt.title("gradient descent for y=x**3")
    plt.plot(list,grad_descent,color='g',marker='o')
    plt.show()

# %%
gradient_function(lambda x: x**3,lambda x:3x*2)
